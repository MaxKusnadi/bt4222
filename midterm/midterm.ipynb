# %% [markdown]
# # Midterm Assignment: McDonald's Sentiment Data Analysis

# %% [markdown]
# ## Problem
#
# McDonald’s receives thousands of consumer comment on their website every day and many of them are negative. Their corporate employees do not have the time to browse through every single comment, but they do want to read a subset that they are most interested in. In particular, articles about the rude service of their employees have recently surfaced on social media. In order to take appropriate action, they would now like to review comments about **rude service**.
#
# You are hired to develop a system that ranks each comment by the **likelihood that it is referring to rude service**. They will use this system to build a “rudeness dashboard” for their corporate employees, so that the employees can spend a few minutes each day examining the **most relevant recent comments**.
#
#
# ## Data
#
# McDonald’s used the CrowdFlower platform to pay humans to hand-annotate approximately 1500 comments with the type of complaint. The list of complaint types can be found below, with the encoding used listed in parentheses:
# - Bad Food (BadFood)
# - Bad Neighborhood (ScaryMcDs)
# - Cost (Cost)
# - Dirty Location (Filthy)
# - Missing Item (MissingFood)
# - Problem with Order (OrderProblem)
# - Rude Service (RudeService)
# - Slow Service (SlowService)
# - None of the above (na)
#
# You will be asked to perform some tasks. In the midst of these tasks, some MCQs will be asked. You are to select the best possible option as your answer. Please answer them accordingly.

# %%
# for Python 2: use print only as a function
from __future__ import print_function

# %% [markdown]
# ## Task 1
#
# Read **'mcdonalds.csv'** into a pandas DataFrame and examine it. (Instructions: mcdonalds.csv can be found in “IVLE Workbin > Midterm Assignment”)
#
# A description of the more important columns to get you started:
# - The **policies_violated** column lists the type of complaint. If there is more than one type, the types are separated by newline characters.
# - The **policies_violated:confidence** column lists CrowdFlower's confidence in the judgments of its human annotators for that row (higher is better).
# - The **city** column is the McDonald's location.
# - The **review** column is the actual text comment.
#
# **Please answer Question 1 as in midterm.pdf.**

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("mcdonalds.csv")
data.head()
# Out:
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  679455653   False   finalized                   3      2/21/15 0:36
# 1  679455654   False   finalized                   3      2/21/15 0:27
# 2  679455655   False   finalized                   3      2/21/15 0:26
# 3  679455656   False   finalized                   3      2/21/15 0:27
# 4  679455657   False   finalized                   3      2/21/15 0:27
#
#                    policies_violated policies_violated:confidence     city  \
# 0  RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667  Atlanta
# 1                        RudeService                            1  Atlanta
# 2          SlowService\nOrderProblem                     1.0\n1.0  Atlanta
# 3                                 na                       0.6667  Atlanta
# 4                        RudeService                            1  Atlanta
#
#    policies_violated_gold                                             review  \
# 0                     NaN  I'm not a huge mcds lover, but I've been to be...
# 1                     NaN  Terrible customer service. ŒæI came in at 9:30...
# 2                     NaN  First they "lost" my order, actually they gave...
# 3                     NaN  I see I'm not the only one giving 1 star. Only...
# 4                     NaN  Well, it's McDonald's, so you know what the fo...
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
print(data.loc[127].review)
# Out:
# Ok I'm waiting for like 10 minutes to place my order with the staff walking back & forth just looking at me like I'm crazy. And another 10 minutes or so before i got my food, This location use to be my stop in the mornings when I worked near here but they have fallen way off.

# %% [markdown]
# ## Task 2
#
# Remove any rows from the DataFrame in which the policies_violated column has a null value.
# - **Note**: Null values are also known as “missing values”, and are encoded in pandas with the special value “NaN’. This is different from the “na” encoding used by CrowdFlower to denote “None of the above”. Rows that contain “na” should not be removed.
#
# **Please answer Questions 2 and 3 as in midterm.pdf.**

# %%
data['city'].isnull().sum()
# Out:
# 87

# %%
data['policies_violated'].notnull().sum()
# Out:
# 1471

# %%
data_clean = data[data['policies_violated'].notnull()]
data_clean.head(3)
# Out:
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  679455653   False   finalized                   3      2/21/15 0:36
# 1  679455654   False   finalized                   3      2/21/15 0:27
# 2  679455655   False   finalized                   3      2/21/15 0:26
#
#                    policies_violated policies_violated:confidence     city  \
# 0  RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667  Atlanta
# 1                        RudeService                            1  Atlanta
# 2          SlowService\nOrderProblem                     1.0\n1.0  Atlanta
#
#    policies_violated_gold                                             review  \
# 0                     NaN  I'm not a huge mcds lover, but I've been to be...
# 1                     NaN  Terrible customer service. ŒæI came in at 9:30...
# 2                     NaN  First they "lost" my order, actually they gave...
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN

# %%
data_clean.shape
# Out:
# (1471, 11)

# %% [markdown]
# ## Task 3
#
# Add a new column to the DataFrame called **"rude"** that is 1 if the **policies_violated** column contains the text "RudeService", and 0 if the **policies_violated** column does not contain "RudeService". The "rude" column is going to be your response variable, so check how many zeros and ones it contains.
#
# **Please answer Question 4 as in midterm.pdf.**

# %%
def find_rude_service(text):
    c = text.find('RudeService')
    return 1 if c != -1 else 0

# %%
data_clean['rude'] = data_clean['policies_violated'].apply(find_rude_service)
# Out:
# /home/max/school/bt4222/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_clean.head()
# Out:
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  679455653   False   finalized                   3      2/21/15 0:36
# 1  679455654   False   finalized                   3      2/21/15 0:27
# 2  679455655   False   finalized                   3      2/21/15 0:26
# 3  679455656   False   finalized                   3      2/21/15 0:27
# 4  679455657   False   finalized                   3      2/21/15 0:27
#
#                    policies_violated policies_violated:confidence     city  \
# 0  RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667  Atlanta
# 1                        RudeService                            1  Atlanta
# 2          SlowService\nOrderProblem                     1.0\n1.0  Atlanta
# 3                                 na                       0.6667  Atlanta
# 4                        RudeService                            1  Atlanta
#
#    policies_violated_gold                                             review  \
# 0                     NaN  I'm not a huge mcds lover, but I've been to be...
# 1                     NaN  Terrible customer service. ŒæI came in at 9:30...
# 2                     NaN  First they "lost" my order, actually they gave...
# 3                     NaN  I see I'm not the only one giving 1 star. Only...
# 4                     NaN  Well, it's McDonald's, so you know what the fo...
#
#    Unnamed: 10  rude
# 0          NaN     1
# 1          NaN     1
# 2          NaN     0
# 3          NaN     0
# 4          NaN     1

# %%
data_clean.shape
# Out:
# (1471, 12)

# %%
data_clean[data_clean['rude'] == 0]
# Out:
#        _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 2     679455655   False   finalized                   3      2/21/15 0:26
# 3     679455656   False   finalized                   3      2/21/15 0:27
# 5     679455658   False   finalized                   3      2/21/15 0:13
# 6     679455659   False   finalized                   3      2/21/15 0:36
# 9     679455662   False   finalized                   3      2/21/15 0:12
# 10    679455663   False   finalized                   3      2/21/15 0:38
# 13    679455666   False   finalized                   3      2/21/15 0:15
# 15    679455668   False   finalized                   3      2/21/15 0:38
# 16    679455669   False   finalized                   3      2/21/15 2:30
# 17    679455670   False   finalized                   3      2/21/15 0:15
# 18    679455671   False   finalized                   3      2/21/15 0:44
# 20    679455673   False   finalized                   3      2/21/15 1:07
# 21    679455674   False   finalized                   3      2/21/15 0:43
# 23    679455676   False   finalized                   3      2/21/15 0:28
# 24    679455677   False   finalized                   3      2/21/15 0:16
# 25    679455678   False   finalized                   3      2/21/15 0:13
# 27    679455680   False   finalized                   3      2/21/15 0:15
# 29    679455682   False   finalized                   3      2/21/15 0:37
# 30    679455683   False   finalized                   3      2/21/15 0:15
# 32    679455685   False   finalized                   3      2/21/15 0:09
# 35    679455688   False   finalized                   3      2/21/15 0:36
# 36    679455689   False   finalized                   3      2/21/15 0:29
# 38    679455691   False   finalized                   3      2/21/15 1:03
# 40    679455693   False   finalized                   3      2/21/15 1:02
# 41    679455694   False   finalized                   3      2/21/15 0:09
# 42    679455695   False   finalized                   3      2/21/15 0:36
# 43    679455696   False   finalized                   3      2/21/15 0:20
# 44    679455697   False   finalized                   3      2/21/15 0:18
# 45    679455698   False   finalized                   3      2/21/15 0:18
# 46    679455699   False   finalized                   3      2/21/15 0:13
# ...         ...     ...         ...                 ...               ...
# 1482  679457165   False   finalized                   3      2/21/15 0:36
# 1483  679457166   False   finalized                   3      2/21/15 0:44
# 1484  679457167   False   finalized                   3      2/21/15 0:15
# 1486  679457169   False   finalized                   3      2/21/15 0:13
# 1489  679457172   False   finalized                   3      2/21/15 0:32
# 1490  679457173   False   finalized                   3      2/21/15 0:43
# 1491  679457174   False   finalized                   3      2/21/15 0:54
# 1492  679457175   False   finalized                   3      2/21/15 0:20
# 1494  679457177   False   finalized                   3      2/21/15 0:40
# 1495  679457178   False   finalized                   3      2/21/15 0:37
# 1496  679457179   False   finalized                   3      2/21/15 0:15
# 1497  679457180   False   finalized                   3      2/21/15 0:21
# 1498  679457181   False   finalized                   3      2/21/15 0:38
# 1500  679472293   False   finalized                   3      2/21/15 0:44
# 1501  679473526   False   finalized                   3      2/21/15 0:17
# 1503  679480418   False   finalized                   3      2/21/15 0:54
# 1506  679483385   False   finalized                   3      2/21/15 0:21
# 1507  679483735   False   finalized                   3      2/21/15 0:20
# 1508  679484306   False   finalized                   3      2/21/15 0:28
# 1510  679485181   False   finalized                   3      2/21/15 0:36
# 1513  679494608   False   finalized                   3      2/21/15 0:34
# 1514  679495317   False   finalized                   3      2/21/15 0:09
# 1515  679495463   False   finalized                   3      2/21/15 0:45
# 1516  679495976   False   finalized                   3      2/21/15 1:01
# 1518  679499048   False   finalized                   3      2/21/15 0:34
# 1520  679500008   False   finalized                   3      2/21/15 0:13
# 1521  679500224   False   finalized                   3      2/21/15 0:27
# 1522  679500608   False   finalized                   3      2/21/15 0:24
# 1523  679501257   False   finalized                   3      2/21/15 0:32
# 1524  679501402   False   finalized                   3      2/21/15 0:27
#
#                       policies_violated policies_violated:confidence  \
# 2             SlowService\nOrderProblem                     1.0\n1.0
# 3                                    na                       0.6667
# 5                  BadFood\nSlowService               0.7111\n0.6444
# 6                SlowService\nScaryMcDs               0.6562\n0.6562
# 9                                    na                            1
# 10                          SlowService                            1
# 13                          SlowService                            1
# 15               SlowService\nScaryMcDs               0.7112\n0.6641
# 16    SlowService\nMissingFood\nBadFood                1.0\n1.0\n1.0
# 17                          SlowService                            1
# 18                          SlowService                       0.7003
# 20                              BadFood                       0.6923
# 21                            ScaryMcDs                       0.6458
# 23                              BadFood                            1
# 24                         OrderProblem                       0.6667
# 25                              BadFood                            1
# 27                      Filthy\nBadFood                  1.0\n0.7037
# 29                          SlowService                       0.6416
# 30                 SlowService\nBadFood                  1.0\n0.6523
# 32                                   na                       0.6641
# 35                          MissingFood                       0.7084
# 36                                   na                       0.6588
# 38                                   na                            1
# 40                              BadFood                            1
# 41                          SlowService                            1
# 42                    SlowService\nCost                     1.0\n1.0
# 43            SlowService\nOrderProblem                  1.0\n0.6909
# 44                    Cost\nMissingFood                  1.0\n0.6761
# 45                                   na                       0.6875
# 46                              BadFood                            1
# ...                                 ...                          ...
# 1482                                 na                            1
# 1483                       OrderProblem                       0.6945
# 1484                                 na                            1
# 1486                            BadFood                            1
# 1489                        SlowService                       0.6817
# 1490                       OrderProblem                       0.6377
# 1491          SlowService\nOrderProblem                  1.0\n0.7125
# 1492                        SlowService                            1
# 1494                        SlowService                            1
# 1495                                 na                            1
# 1496                                 na                       0.6523
# 1497                        SlowService                         0.65
# 1498                            BadFood                            1
# 1500                        SlowService                            1
# 1501                      na\nScaryMcDs                0.676\n0.6529
# 1503                          ScaryMcDs                       0.7125
# 1506                                 na                            1
# 1507                          ScaryMcDs                            1
# 1508                                 na                            1
# 1510                            BadFood                            1
# 1513                       OrderProblem                            1
# 1514                        SlowService                       0.6246
# 1515                                 na                            1
# 1516                       OrderProblem                            1
# 1518                       OrderProblem                            1
# 1520                       OrderProblem                       0.6754
# 1521       SlowService\nFilthy\nBadFood                1.0\n1.0\n1.0
# 1522                          ScaryMcDs                       0.6458
# 1523                          ScaryMcDs                       0.6407
# 1524             ScaryMcDs\nSlowService                  1.0\n0.6667
#
#              city  policies_violated_gold  \
# 2         Atlanta                     NaN
# 3         Atlanta                     NaN
# 5         Atlanta                     NaN
# 6         Atlanta                     NaN
# 9         Atlanta                     NaN
# 10        Atlanta                     NaN
# 13        Atlanta                     NaN
# 15        Atlanta                     NaN
# 16        Atlanta                     NaN
# 17        Atlanta                     NaN
# 18        Atlanta                     NaN
# 20        Atlanta                     NaN
# 21        Atlanta                     NaN
# 23        Atlanta                     NaN
# 24        Atlanta                     NaN
# 25        Atlanta                     NaN
# 27        Atlanta                     NaN
# 29        Atlanta                     NaN
# 30        Atlanta                     NaN
# 32        Atlanta                     NaN
# 35        Atlanta                     NaN
# 36        Atlanta                     NaN
# 38        Atlanta                     NaN
# 40        Atlanta                     NaN
# 41        Atlanta                     NaN
# 42        Atlanta                     NaN
# 43        Atlanta                     NaN
# 44        Atlanta                     NaN
# 45        Atlanta                     NaN
# 46        Atlanta                     NaN
# ...           ...                     ...
# 1482          NaN                     NaN
# 1483          NaN                     NaN
# 1484          NaN                     NaN
# 1486          NaN                     NaN
# 1489          NaN                     NaN
# 1490          NaN                     NaN
# 1491          NaN                     NaN
# 1492          NaN                     NaN
# 1494          NaN                     NaN
# 1495          NaN                     NaN
# 1496          NaN                     NaN
# 1497          NaN                     NaN
# 1498          NaN                     NaN
# 1500    Las Vegas                     NaN
# 1501      Chicago                     NaN
# 1503     New York                     NaN
# 1506    Las Vegas                     NaN
# 1507      Chicago                     NaN
# 1508       Dallas                     NaN
# 1510    Las Vegas                     NaN
# 1513      Chicago                     NaN
# 1514      Houston                     NaN
# 1515    Las Vegas                     NaN
# 1516     New York                     NaN
# 1518    Las Vegas                     NaN
# 1520     Portland                     NaN
# 1521      Houston                     NaN
# 1522     New York                     NaN
# 1523      Chicago                     NaN
# 1524  Los Angeles                     NaN
#
#                                                  review  Unnamed: 10  rude
# 2     First they "lost" my order, actually they gave...          NaN     0
# 3     I see I'm not the only one giving 1 star. Only...          NaN     0
# 5     This has to be one of the worst and slowest Mc...          NaN     0
# 6     I'm not crazy about this McDonald's. ŒæThis is...          NaN     0
# 9     This McDonald's has gotten much better. Usuall...          NaN     0
# 10    Let's start here only reason I came into McDon...          NaN     0
# 13    Believe it or not, this used to be q really go...          NaN     0
# 15    25 minutes in drive through line. Gunshots fro...          NaN     0
# 16    Super slow service, food's terrible like its b...          NaN     0
# 17    SLOW-SLOW-SLOW! ŒæDon't go here if you have a ...          NaN     0
# 18    On your way to the airport or just cruising do...          NaN     0
# 20    I had the McCafe Mocha and must say that it wa...          NaN     0
# 21    GHETTO!! went in yesterday just to get a soda ...          NaN     0
# 23    I usually hit the drive thru once or twice a w...          NaN     0
# 24    What a joke.Don't do take out as you will not ...          NaN     0
# 25    I wish I can give zero stars. Freezing cold re...          NaN     0
# 27    I don't think this location deserves even one ...          NaN     0
# 29    the managers at this mcdonalds are awesome but...          NaN     0
# 30    It had been a while since I had stopped at thi...          NaN     0
# 32    This has got to be one of the busiest McDonald...          NaN     0
# 35    The ice cream machine is always "down" after 1...          NaN     0
# 36    Regular McDonald's. Close to the highway which...          NaN     0
# 38    I highly recommend this McDonalds!******if and...          NaN     0
# 40    I know i shouldn't need to ask but experience ...          NaN     0
# 41    I don't often eat at McDonald's, or ever in fa...          NaN     0
# 42    Little bit more expensive than other Mickey De...          NaN     0
# 43    This is the McDonald's inside the Northside Ho...          NaN     0
# 44    The worst McDonalds ever. Complete chaos. The ...          NaN     0
# 45    A captive audience of transient visitors and e...          NaN     0
# 46    AND STILL FRENCH FRY CHAMP.........The burger ...          NaN     0
# ...                                                 ...          ...   ...
# 1482                       They are open. Good service.          NaN     0
# 1483  I asked for coffee with milk, and the lively m...          NaN     0
# 1484  All the drive through employees were very poli...          NaN     0
# 1486  I live very close, stop this morning at 5:50 a...          NaN     0
# 1489  We loooooove junk food and we love McDonalds B...          NaN     0
# 1490  THIS PLACE IS A HOT MESS !! Disgusting !! The ...          NaN     0
# 1491  Everytime I go to this McDonalds I swear I wil...          NaN     0
# 1492  Horrible services, very long waiting line, 15 ...          NaN     0
# 1494  Clean restaurant. Always packed and you can be...          NaN     0
# 1495                 very good mcdonald's ,good service          NaN     0
# 1496  Came here for the McCafe.Coffee was a little l...          NaN     0
# 1497  I actually got in an accident trying to leave ...          NaN     0
# 1498  Came here for breakfast and there was total ch...          NaN     0
# 1500  If they went any slower, I would have grown a ...          NaN     0
# 1501  I am very amazed at the hard working employees...          NaN     0
# 1503  Best place on Park Avenue to meet homeless peo...          NaN     0
# 1506  My mom needed to meet a client to pick up docu...          NaN     0
# 1507  This is not a family-friendly location. There'...          NaN     0
# 1508  I love this McDonalds! The workers are always ...          NaN     0
# 1510  WORST MCDONALDS EVER!Every single time we have...          NaN     0
# 1513  Every time I come here they mess up my order.....          NaN     0
# 1514  Don't go here if you're looking for fast food....          NaN     0
# 1515  Ok ok ok, I know it's only a McDonald's, BUT t...          NaN     0
# 1516  Okay so I came in here yesterday around 4:15 P...          NaN     0
# 1518  Breakfast for the family and kids. Œæ8 of us. ...          NaN     0
# 1520  I enjoyed the part where I repeatedly asked if...          NaN     0
# 1521  Worst McDonalds I've been in in a long time! D...          NaN     0
# 1522  When I am really craving for McDonald's, this ...          NaN     0
# 1523  Two points right out of the gate: 1. Thuggery ...          NaN     0
# 1524  I wanted to grab breakfast one morning before ...          NaN     0
#
# [968 rows x 12 columns]

# %%
len(data_clean[data_clean['rude'] == 0]) / len(data_clean)
# Out:
# 0.6580557443915703

# %% [markdown]
# ## Task 4
#
# Define X using the **review** column and y using the **rude** column. Split X and y into training and testing sets (using the parameter **`random_state=1`**). Use CountVectorizer (with the **default parameters**) to create document-term matrices from X_train and X_test.
# - Note: Please remember to follow the instructions carefully by setting the parameters as required for reproducibility of results.
#
# **Please answer Questions 5 and 6 as in midterm.pdf.**

# %%
X = data_clean['review']
Y = data_clean['rude']

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()

# %%
vect.fit_transform(X_train)
# Out:
# <1103x7300 sparse matrix of type '<class 'numpy.int64'>'
# 	with 70807 stored elements in Compressed Sparse Row format>

# %%
a = vect.transform(X_test).toarray()

# %%
count_true = 0
count_false = 0
for x in a[24]:
    if x == 1:
        count_true += 1
    else:
        count_false += 1
print(len(a[24]))
print(count_true)
print(count_false)
print(count_true + count_false)
# Out:
# 7300
# 3
# 7297
# 7300

# %% [markdown]
# ## Task 5
#
# Fit a Multinomial Naive Bayes model to the training set, calculate the **predicted probabilities** for the testing set, and then calculate the AUC. Repeat this task using a logistic regression model to compare which of the two models achieves a better AUC.
# - **Note**: McDonald’s requires you to rank the comments by the likelihood that they refer to rude service. In this case, classification accuracy is NOT the relevant evaluation metric. Area Under Curve (AUC) is a more useful evaluation metric for this scenario, since it measures the ability of the classifier to assign higher predicted probabilities to positive instances than to negative instances.
#
# **Please answer Questions 7, 8 and 9 as in midterm.pdf.**

# %%
x_dtm = vect.fit_transform(X_train)
x_dtm
# Out:
# <1103x7300 sparse matrix of type '<class 'numpy.int64'>'
# 	with 70807 stored elements in Compressed Sparse Row format>

# %%
x_test_dtm = vect.transform(X_test)
x_test_dtm
# Out:
# <368x7300 sparse matrix of type '<class 'numpy.int64'>'
# 	with 22035 stored elements in Compressed Sparse Row format>

# %%
# import and instantiate a Multinomial Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %%
# %time nb.fit(x_dtm, y_train)
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 2.25 ms
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_predict = nb.predict(x_test_dtm[0:5])
y_predict
# Out:
# array([1, 0, 1, 0, 0])

# %%
y_predict[:5]
# Out:
# array([1, 0, 1, 0, 0])

# %%
from sklearn import metrics

# %%
y_pred_prob = nb.predict_proba(x_test_dtm)[:, 1]
y_pred_prob
# Out:
# array([  9.99234643e-01,   2.59242971e-01,   8.57868677e-01,
#          2.67695702e-06,   2.68548521e-01,   9.97469782e-01,
#          7.40699844e-04,   1.11406133e-09,   1.91914636e-01,
#          4.11011564e-01,   9.97466984e-01,   5.38284222e-02,
#          6.80854939e-07,   8.34493700e-01,   2.15804856e-01,
#          9.95641179e-01,   1.19139453e-04,   1.00000000e+00,
#          2.95609981e-03,   8.56160253e-02,   1.07358615e-07,
#          1.24737099e-03,   3.17424163e-03,   9.99811373e-01,
#          2.97503091e-01,   1.69157013e-07,   5.73190648e-01,
#          1.80537581e-01,   9.23675492e-02,   7.26950593e-01,
#          7.31090780e-01,   9.99998319e-01,   9.99999992e-01,
#          1.53328396e-06,   9.99999991e-01,   1.84177211e-02,
#          3.56210035e-01,   5.82027503e-01,   5.44354319e-04,
#          2.65523485e-01,   1.27716883e-03,   9.76737932e-04,
#          7.18630183e-01,   3.16802348e-02,   1.07181170e-09,
#          9.51213834e-01,   8.21426820e-03,   9.99313337e-01,
#          1.12689902e-01,   9.95364682e-01,   6.35333762e-02,
#          6.51025349e-02,   1.98769973e-02,   9.63771630e-02,
#          4.15269133e-02,   7.52907084e-01,   1.36875210e-01,
#          1.34489934e-01,   5.34999423e-02,   2.38309462e-02,
#          7.73172045e-01,   1.09407331e-01,   1.70789664e-02,
#          9.46175636e-02,   8.66709161e-01,   5.25246394e-06,
#          9.06930083e-01,   4.11835891e-02,   1.49046263e-02,
#          9.17881794e-01,   2.64007030e-01,   4.30745609e-01,
#          3.16940699e-01,   8.17359956e-01,   8.75577892e-02,
#          2.32406910e-03,   9.89798869e-01,   2.31100770e-01,
#          4.62416150e-06,   2.11488207e-05,   4.61278481e-02,
#          7.15968077e-02,   3.48265591e-02,   9.93101417e-01,
#          1.93209183e-02,   9.12358290e-01,   1.10889762e-01,
#          7.90055749e-01,   2.99801740e-02,   3.28602515e-02,
#          5.83032355e-01,   3.55398218e-01,   1.06500022e-01,
#          6.96813503e-03,   2.20507028e-02,   6.68321209e-02,
#          2.37440946e-01,   1.62768779e-01,   1.51800274e-02,
#          8.01361891e-01,   5.17222748e-03,   3.78500292e-01,
#          6.68674718e-03,   2.33724064e-02,   1.78075674e-01,
#          2.24826261e-01,   9.50499321e-01,   7.73033391e-01,
#          8.65016861e-01,   1.97227265e-01,   7.62118254e-03,
#          1.20105596e-02,   1.83100967e-01,   1.66874399e-01,
#          2.96210667e-01,   9.99206986e-01,   9.27933401e-01,
#          1.58165396e-01,   9.81277364e-01,   4.03480421e-01,
#          9.13980156e-01,   2.98164783e-04,   1.98784584e-01,
#          4.51634843e-02,   8.40781452e-01,   3.50823916e-01,
#          2.49143233e-03,   6.80965974e-01,   5.99582986e-01,
#          9.71359439e-01,   5.56063466e-02,   6.94219069e-02,
#          7.43083172e-01,   4.00529154e-01,   2.91994854e-03,
#          4.60335045e-01,   1.97191647e-01,   1.62130880e-01,
#          4.40550502e-01,   6.00042509e-01,   2.79210518e-01,
#          8.64680958e-01,   1.83600821e-01,   8.25740703e-01,
#          3.97558899e-01,   3.88167791e-02,   3.99902332e-03,
#          9.93777148e-01,   6.86559422e-03,   3.15259870e-02,
#          4.57362136e-01,   8.03645980e-01,   2.92480009e-01,
#          9.99999940e-01,   9.83885208e-01,   2.18415659e-03,
#          6.52391945e-02,   9.67438120e-01,   1.73058773e-01,
#          5.32236047e-01,   5.55278231e-01,   6.40695120e-04,
#          1.09493274e-05,   7.94400540e-01])

# %%
metrics.roc_auc_score(y_test, y_log_pred_prob)
# Out:
# 0.8233667143538389

# %%
metrics.roc_auc_score(y_test, y_pred_prob) - metrics.roc_auc_score(y_test, y_log_pred_prob)
# Out:
# 0.019233826100778839

# %% [markdown]
# ## Task 6
#
# Using Naive Bayes, try **tuning CountVectorizer** using some of the techniques we learned in class. Check the testing set AUC after each change, and find the set of parameters that increases AUC the most. (This is meant for your own learning experience)
# - **Hint**: It is highly recommended that you adapt the **`tokenize_test()`** function from class for this purpose, since it will allow you to iterate quickly through different sets of parameters.
#
# **Please answer Questions 10 and 11 as in midterm.pdf.**

# %%
def tokenize_test(vect):
    # Transform fit
    x_dtm = vect.fit_transform(X_train)
    x_test_dtm = vect.transform(X_test)
    
    # import and instantiate a Multinomial Naive Bayes model
    from sklearn.naive_bayes import MultinomialNB
    nb = MultinomialNB()
    
    nb.fit(x_dtm, y_train)
    y_pred_prob = nb.predict_proba(x_test_dtm)[:, 1]
    
    from sklearn import metrics
    return metrics.roc_auc_score(y_test, y_pred_prob)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()

# %%
tokenize_test(vect)
# Out:
# 0.84260054045461774

# %%
# max_df
vect = CountVectorizer(max_df=0.5)
tokenize_test(vect)
# Out:
# 0.84488952471785073

# %%
# min
vect = CountVectorizer(min_df=2)
tokenize_test(vect)
# Out:
# 0.84458750596089649

# %%
# stopwords
vect = CountVectorizer(stop_words='english')
tokenize_test(vect)
# Out:
# 0.85352090287712601

# %%
vect = CountVectorizer(max_features=1000)
tokenize_test(vect)
# Out:
# 0.83009060562708625

# %%
# include 1-grams and 2-grams, and only keep terms that appear in at least 2 documents
vect = CountVectorizer(ngram_range=(1, 2))
tokenize_test(vect)
# Out:
# 0.81959942775393424

# %%
vect = CountVectorizer(min_df=4, max_df=0.3, stop_words='english')
tokenize_test(vect)
# Out:
# 0.86215228103640118

# %%
x_dtm = vect.fit_transform(X_train)
x_dtm
# Out:
# <1103x1732 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31806 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Task 7
#
# The city column might be predictive of the response, but we are currently not using it as a feature. We will now explore to see if we can increase the AUC by adding city to the model. You are to do the following:
# 1. Create a new DataFrame column, review_city, that concatenates the review text with the city text. One easy way to combine string columns in pandas is by using the `Series.str.cat()` method. Make sure to use the whitespace character as a separator, as well as replacing null city values with a reasonable string value such as ‘na’.
# 2. Redefine X using the review_city column, and re-split X and y into training and testing sets (using the parameter `random_state=1`).
# 3. By allowing for English stopwords removal, and setting the following parameters as `max_df = 0.3`, `min_df=4` in the CountVectorizer, check whether it has increased or decreased the AUC.
#
# **Please answer Question 12 as in midterm.pdf.**

# %%
def get_review_city(text, city):
    return pd.Series([text, city]).str.cat(sep=' ', na_rep='na')

# %%
data_clean['review_city'] = data_clean.apply(lambda x: get_review_city(x['review'], x['city']), axis=1)
data_clean
# Out:
# /home/max/school/bt4222/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#        _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     679455653   False   finalized                   3      2/21/15 0:36
# 1     679455654   False   finalized                   3      2/21/15 0:27
# 2     679455655   False   finalized                   3      2/21/15 0:26
# 3     679455656   False   finalized                   3      2/21/15 0:27
# 4     679455657   False   finalized                   3      2/21/15 0:27
# 5     679455658   False   finalized                   3      2/21/15 0:13
# 6     679455659   False   finalized                   3      2/21/15 0:36
# 7     679455660   False   finalized                   3      2/21/15 0:15
# 8     679455661   False   finalized                   3      2/21/15 0:29
# 9     679455662   False   finalized                   3      2/21/15 0:12
# 10    679455663   False   finalized                   3      2/21/15 0:38
# 11    679455664   False   finalized                   3      2/21/15 0:40
# 12    679455665   False   finalized                   3      2/21/15 0:24
# 13    679455666   False   finalized                   3      2/21/15 0:15
# 14    679455667   False   finalized                   3      2/21/15 0:37
# 14        BadFood\nRudeService\nSlowService          1.0\n0.6928\n0.6655
# 15                   SlowService\nScaryMcDs               0.7112\n0.6641
# 16        SlowService\nMissingFood\nBadFood                1.0\n1.0\n1.0
# 17                              SlowService                            1
# 18                              SlowService                       0.7003
# 19                              RudeService                            1
# 20                                  BadFood                       0.6923
# 21                                ScaryMcDs                       0.6458
# 22                RudeService\nOrderProblem                  1.0\n0.7179
# 23                                  BadFood                            1
# 24                             OrderProblem                       0.6667
# 25                                  BadFood                            1
# 26                     RudeService\nBadFood                  1.0\n0.6216
# 27                          Filthy\nBadFood                  1.0\n0.7037
# 28                 SlowService\nRudeService                     1.0\n1.0
# 29                              SlowService                       0.6416
# ...                                     ...                          ...
# 1495                                     na                            1
# 1496                                     na                       0.6523
# 1497                            SlowService                         0.65
# 1498                                BadFood                            1
# 1499              OrderProblem\nRudeService                  1.0\n0.6966
# 1500                            SlowService                            1
# 1501                          na\nScaryMcDs                0.676\n0.6529
# 1502                            RudeService                            1
# 1503                              ScaryMcDs                       0.7125
# 1504               RudeService\nSlowService                  1.0\n0.7037
# 1505                 RudeService\nScaryMcDs                  1.0\n0.6564
# 1506                                     na                            1
# 1507                              ScaryMcDs                            1
# 1508                                     na                            1
# 1509                   BadFood\nRudeService                  1.0\n0.6909
# 1510                                BadFood                            1
# 1511              RudeService\nOrderProblem                  1.0\n0.6585
# 1512              OrderProblem\nRudeService               0.7056\n0.6377
# 1513                           OrderProblem                            1
# 1514                            SlowService                       0.6246
# 1515                                     na                            1
# 1516                           OrderProblem                            1
# 1517              OrderProblem\nRudeService                  1.0\n0.6786
# 1518                           OrderProblem                            1
# 1519                            RudeService                            1
# 1520                           OrderProblem                       0.6754
# 1521           SlowService\nFilthy\nBadFood                1.0\n1.0\n1.0
# 1522                              ScaryMcDs                       0.6458
# 1523                              ScaryMcDs                       0.6407
# 1524                 ScaryMcDs\nSlowService                  1.0\n0.6667
#
#              city  policies_violated_gold  \
# 0         Atlanta                     NaN
# 1         Atlanta                     NaN
# 2         Atlanta                     NaN
# 3         Atlanta                     NaN
# 4         Atlanta                     NaN
# 5         Atlanta                     NaN
# 6         Atlanta                     NaN
# 7         Atlanta                     NaN
# 8         Atlanta                     NaN
# 9         Atlanta                     NaN
# 10        Atlanta                     NaN
# 11        Atlanta                     NaN
# 12        Atlanta                     NaN
# 13        Atlanta                     NaN
# 14        Atlanta                     NaN
# 15        Atlanta                     NaN
# 16        Atlanta                     NaN
# 17        Atlanta                     NaN
# 18        Atlanta                     NaN
# 19        Atlanta                     NaN
# 20        Atlanta                     NaN
# 21        Atlanta                     NaN
# 22        Atlanta                     NaN
# 23        Atlanta                     NaN
# 24        Atlanta                     NaN
# 25        Atlanta                     NaN
# 26        Atlanta                     NaN
# 27        Atlanta                     NaN
# 28        Atlanta                     NaN
# 29        Atlanta                     NaN
# ...           ...                     ...
# 1495          NaN                     NaN
# 1496          NaN                     NaN
# 1497          NaN                     NaN
# 1498          NaN                     NaN
# 1499      Chicago                     NaN
# 1500    Las Vegas                     NaN
# 1501      Chicago                     NaN
# 1502      Chicago                     NaN
# 1503     New York                     NaN
# 1504  Los Angeles                     NaN
# 1505      Chicago                     NaN
# 1506    Las Vegas                     NaN
# 1507      Chicago                     NaN
# 1508       Dallas                     NaN
# 1509     New York                     NaN
# 1510    Las Vegas                     NaN
# 1511    Las Vegas                     NaN
# 1512      Chicago                     NaN
# 1513      Chicago                     NaN
# 1514      Houston                     NaN
# 1515    Las Vegas                     NaN
# 1516     New York                     NaN
# 1517      Houston                     NaN
# 1518    Las Vegas                     NaN
# 1519          NaN                     NaN
# 1520     Portland                     NaN
# 1521      Houston                     NaN
# 1522     New York                     NaN
# 1523      Chicago                     NaN
# 1524  Los Angeles                     NaN
#
#                                                  review  Unnamed: 10  rude  \
# 0     I'm not a huge mcds lover, but I've been to be...          NaN     1
# 1     Terrible customer service. ŒæI came in at 9:30...          NaN     1
# 2     First they "lost" my order, actually they gave...          NaN     0
# 3     I see I'm not the only one giving 1 star. Only...          NaN     0
# 4     Well, it's McDonald's, so you know what the fo...          NaN     1
# 5     This has to be one of the worst and slowest Mc...          NaN     0
# 6     I'm not crazy about this McDonald's. ŒæThis is...          NaN     0
# 7     One Star and I'm beng kind. I blame management...          NaN     1
# 8     Never been upset about any fast food drive thr...          NaN     1
# 9     This McDonald's has gotten much better. Usuall...          NaN     0
# 10    Let's start here only reason I came into McDon...          NaN     0
# 11    Other businesses throughout Metro Atlanta open...          NaN     1
# 12    The drive thru makes them lost a star since my...          NaN     1
# 13    Believe it or not, this used to be q really go...          NaN     0
# 14    As the previous yelpers have already stated, t...          NaN     1
# 15    25 minutes in drive through line. Gunshots fro...          NaN     0
# 16    Super slow service, food's terrible like its b...          NaN     0
# 17    SLOW-SLOW-SLOW! ŒæDon't go here if you have a ...          NaN     0
# 18    On your way to the airport or just cruising do...          NaN     0
# 19    This is the worst McDonalds I have ever seen. ...          NaN     1
# 20    I had the McCafe Mocha and must say that it wa...          NaN     0
# 21    GHETTO!! went in yesterday just to get a soda ...          NaN     0
# 22    I visited mcdonalds on Dec 20, 2011 at 12:54 I...          NaN     1
# 23    I usually hit the drive thru once or twice a w...          NaN     0
# 24    What a joke.Don't do take out as you will not ...          NaN     0
# 25    I wish I can give zero stars. Freezing cold re...          NaN     0
# 26    I agree with most reviewers on this one. Staff...          NaN     1
# 27    I don't think this location deserves even one ...          NaN     0
# 28    This is one rude Mcdonalds! The food takes lon...          NaN     1
# 29    the managers at this mcdonalds are awesome but...          NaN     0
# ...                                                 ...          ...   ...
# 1495                 very good mcdonald's ,good service          NaN     0
# 1496  Came here for the McCafe.Coffee was a little l...          NaN     0
# 1497  I actually got in an accident trying to leave ...          NaN     0
# 1498  Came here for breakfast and there was total ch...          NaN     0
# 1499  I dont like mcdonalds but go once in a great w...          NaN     1
# 1500  If they went any slower, I would have grown a ...          NaN     0
# 1501  I am very amazed at the hard working employees...          NaN     0
# 1502  Managers are rude to customers, I asked if the...          NaN     1
# 1503  Best place on Park Avenue to meet homeless peo...          NaN     0
# 1504  Worst customer service ever!!!!!!!!!!!!over 30...          NaN     1
# 1505  I won't be critical because it was only a Mcdo...          NaN     1
# 1506  My mom needed to meet a client to pick up docu...          NaN     0
# 1507  This is not a family-friendly location. There'...          NaN     0
# 1508  I love this McDonalds! The workers are always ...          NaN     0
# 1509  Really rude workers and customer service was j...          NaN     1
# 1510  WORST MCDONALDS EVER!Every single time we have...          NaN     0
# 1511  Worst service ever!!!! There was so much trash...          NaN     1
# 1512  Normally I don't review a chain unless somethi...          NaN     1
# 1513  Every time I come here they mess up my order.....          NaN     0
# 1514  Don't go here if you're looking for fast food....          NaN     0
# 1515  Ok ok ok, I know it's only a McDonald's, BUT t...          NaN     0
# 1516  Okay so I came in here yesterday around 4:15 P...          NaN     0
# 1517  The drive thru got our order wrong AGAIN. I ca...          NaN     1
# 1518  Breakfast for the family and kids. Œæ8 of us. ...          NaN     0
# 1519  If I could put zero stars, it would deserve th...          NaN     1
# 1520  I enjoyed the part where I repeatedly asked if...          NaN     0
# 1521  Worst McDonalds I've been in in a long time! D...          NaN     0
# 1522  When I am really craving for McDonald's, this ...          NaN     0
# 1523  Two points right out of the gate: 1. Thuggery ...          NaN     0
# 1524  I wanted to grab breakfast one morning before ...          NaN     0
#
#                                             review_city
# 0     I'm not a huge mcds lover, but I've been to be...
# 1     Terrible customer service. ŒæI came in at 9:30...
# 2     First they "lost" my order, actually they gave...
# 3     I see I'm not the only one giving 1 star. Only...
# 4     Well, it's McDonald's, so you know what the fo...
# 5     This has to be one of the worst and slowest Mc...
# 6     I'm not crazy about this McDonald's. ŒæThis is...
# 7     One Star and I'm beng kind. I blame management...
# 8     Never been upset about any fast food drive thr...
# 9     This McDonald's has gotten much better. Usuall...
# 10    Let's start here only reason I came into McDon...
# 11    Other businesses throughout Metro Atlanta open...
# 12    The drive thru makes them lost a star since my...
# 13    Believe it or not, this used to be q really go...
# 14    As the previous yelpers have already stated, t...
# 15    25 minutes in drive through line. Gunshots fro...
# 16    Super slow service, food's terrible like its b...
# 17    SLOW-SLOW-SLOW! ŒæDon't go here if you have a ...
# 18    On your way to the airport or just cruising do...
# 19    This is the worst McDonalds I have ever seen. ...
# 20    I had the McCafe Mocha and must say that it wa...
# 21    GHETTO!! went in yesterday just to get a soda ...
# 22    I visited mcdonalds on Dec 20, 2011 at 12:54 I...
# 23    I usually hit the drive thru once or twice a w...
# 24    What a joke.Don't do take out as you will not ...
# 25    I wish I can give zero stars. Freezing cold re...
# 26    I agree with most reviewers on this one. Staff...
# 27    I don't think this location deserves even one ...
# 28    This is one rude Mcdonalds! The food takes lon...
# 29    the managers at this mcdonalds are awesome but...
# ...                                                 ...
# 1495              very good mcdonald's ,good service na
# 1496  Came here for the McCafe.Coffee was a little l...
# 1497  I actually got in an accident trying to leave ...
# 1498  Came here for breakfast and there was total ch...
# 1499  I dont like mcdonalds but go once in a great w...
# 1500  If they went any slower, I would have grown a ...
# 1501  I am very amazed at the hard working employees...
# 1502  Managers are rude to customers, I asked if the...
# 1503  Best place on Park Avenue to meet homeless peo...
# 1504  Worst customer service ever!!!!!!!!!!!!over 30...
# 1505  I won't be critical because it was only a Mcdo...
# 1506  My mom needed to meet a client to pick up docu...
# 1507  This is not a family-friendly location. There'...
# 1508  I love this McDonalds! The workers are always ...
# 1509  Really rude workers and customer service was j...
# 1510  WORST MCDONALDS EVER!Every single time we have...
# 1511  Worst service ever!!!! There was so much trash...
# 1512  Normally I don't review a chain unless somethi...
# 1513  Every time I come here they mess up my order.....
# 1514  Don't go here if you're looking for fast food....
# 1515  Ok ok ok, I know it's only a McDonald's, BUT t...
# 1516  Okay so I came in here yesterday around 4:15 P...
# 1517  The drive thru got our order wrong AGAIN. I ca...
# 1518  Breakfast for the family and kids. Œæ8 of us. ...
# 1519  If I could put zero stars, it would deserve th...
# 1520  I enjoyed the part where I repeatedly asked if...
# 1521  Worst McDonalds I've been in in a long time! D...
# 1522  When I am really craving for McDonald's, this ...
# 1523  Two points right out of the gate: 1. Thuggery ...
# 1524  I wanted to grab breakfast one morning before ...
#
# [1471 rows x 13 columns]

# %%
X_city = data_clean['review_city']
X_city
# Out:
# 0       I'm not a huge mcds lover, but I've been to be...
# 1       Terrible customer service. ŒæI came in at 9:30...
# 2       First they "lost" my order, actually they gave...
# 3       I see I'm not the only one giving 1 star. Only...
# 4       Well, it's McDonald's, so you know what the fo...
# 5       This has to be one of the worst and slowest Mc...
# 6       I'm not crazy about this McDonald's. ŒæThis is...
# 7       One Star and I'm beng kind. I blame management...
# 8       Never been upset about any fast food drive thr...
# 9       This McDonald's has gotten much better. Usuall...
# 10      Let's start here only reason I came into McDon...
# 11      Other businesses throughout Metro Atlanta open...
# 12      The drive thru makes them lost a star since my...
# 13      Believe it or not, this used to be q really go...
# 14      As the previous yelpers have already stated, t...
# 15      25 minutes in drive through line. Gunshots fro...
# 16      Super slow service, food's terrible like its b...
# 17      SLOW-SLOW-SLOW! ŒæDon't go here if you have a ...
# 18      On your way to the airport or just cruising do...
# 19      This is the worst McDonalds I have ever seen. ...
# 20      I had the McCafe Mocha and must say that it wa...
# 21      GHETTO!! went in yesterday just to get a soda ...
# 22      I visited mcdonalds on Dec 20, 2011 at 12:54 I...
# 23      I usually hit the drive thru once or twice a w...
# 24      What a joke.Don't do take out as you will not ...
# 25      I wish I can give zero stars. Freezing cold re...
# 26      I agree with most reviewers on this one. Staff...
# 27      I don't think this location deserves even one ...
# 28      This is one rude Mcdonalds! The food takes lon...
# 29      the managers at this mcdonalds are awesome but...
#                               ...
# 1495                very good mcdonald's ,good service na
# 1496    Came here for the McCafe.Coffee was a little l...
# 1497    I actually got in an accident trying to leave ...
# 1498    Came here for breakfast and there was total ch...
# 1499    I dont like mcdonalds but go once in a great w...
# 1500    If they went any slower, I would have grown a ...
# 1501    I am very amazed at the hard working employees...
# 1502    Managers are rude to customers, I asked if the...
# 1503    Best place on Park Avenue to meet homeless peo...
# 1504    Worst customer service ever!!!!!!!!!!!!over 30...
# 1505    I won't be critical because it was only a Mcdo...
# 1506    My mom needed to meet a client to pick up docu...
# 1507    This is not a family-friendly location. There'...
# 1508    I love this McDonalds! The workers are always ...
# 1509    Really rude workers and customer service was j...
# 1510    WORST MCDONALDS EVER!Every single time we have...
# 1511    Worst service ever!!!! There was so much trash...
# 1512    Normally I don't review a chain unless somethi...
# 1513    Every time I come here they mess up my order.....
# 1514    Don't go here if you're looking for fast food....
# 1515    Ok ok ok, I know it's only a McDonald's, BUT t...
# 1516    Okay so I came in here yesterday around 4:15 P...
# 1517    The drive thru got our order wrong AGAIN. I ca...
# 1518    Breakfast for the family and kids. Œæ8 of us. ...
# 1519    If I could put zero stars, it would deserve th...
# 1520    I enjoyed the part where I repeatedly asked if...
# 1521    Worst McDonalds I've been in in a long time! D...
# 1522    When I am really craving for McDonald's, this ...
# 1523    Two points right out of the gate: 1. Thuggery ...
# 1524    I wanted to grab breakfast one morning before ...
# Name: review_city, dtype: object

# %%
Y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
# 5       0
# 6       0
# 7       1
# 8       1
# 9       0
# 10      0
# 11      1
# 12      1
# 13      0
# 14      1
# 15      0
# 16      0
# 17      0
# 18      0
# 19      1
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      0
# 26      1
# 27      0
# 28      1
# 29      0
#        ..
# 1495    0
# 1496    0
# 1497    0
# 1498    0
# 1499    1
# 1500    0
# 1501    0
# 1502    1
# 1503    0
# 1504    1
# 1505    1
# 1506    0
# 1507    0
# 1508    0
# 1509    1
# 1510    0
# 1511    1
# 1512    1
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    1
# 1518    0
# 1519    1
# 1520    0
# 1521    0
# 1522    0
# 1523    0
# 1524    0
# Name: rude, dtype: int64

# %%
X_city_train, X_city_test, y_city_train, y_city_test = train_test_split(X_city, Y, random_state=1)

# %%
vect = CountVectorizer(min_df=4, max_df=0.3, stop_words='english')

# %%
# Transform fit
x_dtm = vect.fit_transform(X_city_train)
x_test_dtm = vect.transform(X_city_test)

# import and instantiate a Multinomial Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

nb.fit(x_dtm, y_city_train)
y_pred_prob = nb.predict_proba(x_test_dtm)[:, 1]

from sklearn import metrics
print(metrics.roc_auc_score(y_city_test, y_pred_prob))
# Out:
# 0.864854554125

# %%
metrics.roc_auc_score(y_city_test, y_pred_prob) - 0.86215228103640118
# Out:
# 0.0027022730885392088

# %% [markdown]
# ## Task 8
#
# The **policies_violated:confidence** column may be useful as it is a measure of the training data quality. You are to calculate the **mean confidence** score for each row of your McDonald’s dataset (i.e. X_train together with X_test) and store these mean scores in a new column. For example the confidence scores for the first row are 1.0\r\n0.6667\r\n0.6667, so you should calculate a mean of 0.7778. Here are some of the steps you can follow:
# 1. Using the `Series.str.split()` method, convert the policies_violated:confidence column into lists of one or more “confidence scores”. Save the results as a new DataFrame column called **confidence_list**.
# 2. Apply a function that can calculate the mean of a list of numbers, and pass that function to the `Series.apply()` method of the **confidence_list** column. Save those scores in a new DataFrame column called **confidence_mean**.
#
# **Please answer Question 13 as in midterm.pdf.**

# %%
data_clean['confidence_list'] = data_clean['policies_violated:confidence'].str.split()
data_clean.head(2)
# Out:
# /home/max/school/bt4222/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  679455653   False   finalized                   3      2/21/15 0:36
# 1  679455654   False   finalized                   3      2/21/15 0:27
#
#                    policies_violated policies_violated:confidence     city  \
# 0  RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667  Atlanta
# 1                        RudeService                            1  Atlanta
#
#    policies_violated_gold                                             review  \
# 0                     NaN  I'm not a huge mcds lover, but I've been to be...
# 1                     NaN  Terrible customer service. ŒæI came in at 9:30...
#
#    Unnamed: 10  rude                                        review_city  \
# 0          NaN     1  I'm not a huge mcds lover, but I've been to be...
# 1          NaN     1  Terrible customer service. ŒæI came in at 9:30...
#
#          confidence_list
# 0  [1.0, 0.6667, 0.6667]
# 1                    [1]

# %%
def get_confidence_mean(lst):
    lst = list(map(lambda x: float(x), lst))
    return sum(lst)/len(lst)

# %%
data_clean['confidence_mean'] = data_clean['confidence_list'].apply(get_confidence_mean)
data_clean.head(2)
# Out:
# /home/max/school/bt4222/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  679455653   False   finalized                   3      2/21/15 0:36
# 1  679455654   False   finalized                   3      2/21/15 0:27
#
#                    policies_violated policies_violated:confidence     city  \
# 0  RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667  Atlanta
# 1                        RudeService                            1  Atlanta
#
#    policies_violated_gold                                             review  \
# 0                     NaN  I'm not a huge mcds lover, but I've been to be...
# 1                     NaN  Terrible customer service. ŒæI came in at 9:30...
#
#    Unnamed: 10  rude                                        review_city  \
# 0          NaN     1  I'm not a huge mcds lover, but I've been to be...
# 1          NaN     1  Terrible customer service. ŒæI came in at 9:30...
#
#          confidence_list  confidence_mean
# 0  [1.0, 0.6667, 0.6667]           0.7778
# 1                    [1]           1.0000

# %%
len(data_clean[data_clean['confidence_mean'] == 1])
# Out:
# 785

# %% [markdown]
# We will now like to remove lower-quality rows from the training set to reduce noise. You are to remove all rows from X_train and y_train that have a confidence_mean lower than 0.75.
#
# **Please answer Questions 14 and 15 as in midterm.pdf.**

# %%
data_clean.head()
# Out:
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  679455653   False   finalized                   3      2/21/15 0:36
# 1  679455654   False   finalized                   3      2/21/15 0:27
# 2  679455655   False   finalized                   3      2/21/15 0:26
# 3  679455656   False   finalized                   3      2/21/15 0:27
# 4  679455657   False   finalized                   3      2/21/15 0:27
#
#                    policies_violated policies_violated:confidence     city  \
# 0  RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667  Atlanta
# 1                        RudeService                            1  Atlanta
# 2          SlowService\nOrderProblem                     1.0\n1.0  Atlanta
# 3                                 na                       0.6667  Atlanta
# 4                        RudeService                            1  Atlanta
#
#    policies_violated_gold                                             review  \
# 0                     NaN  I'm not a huge mcds lover, but I've been to be...
# 1                     NaN  Terrible customer service. ŒæI came in at 9:30...
# 2                     NaN  First they "lost" my order, actually they gave...
# 3                     NaN  I see I'm not the only one giving 1 star. Only...
# 4                     NaN  Well, it's McDonald's, so you know what the fo...
#
#    Unnamed: 10  rude                                        review_city  \
# 0          NaN     1  I'm not a huge mcds lover, but I've been to be...
# 1          NaN     1  Terrible customer service. ŒæI came in at 9:30...
# 2          NaN     0  First they "lost" my order, actually they gave...
# 3          NaN     0  I see I'm not the only one giving 1 star. Only...
# 4          NaN     1  Well, it's McDonald's, so you know what the fo...
#
#          confidence_list  confidence_mean
# 0  [1.0, 0.6667, 0.6667]           0.7778
# 1                    [1]           1.0000
# 2             [1.0, 1.0]           1.0000
# 3               [0.6667]           0.6667
# 4                    [1]           1.0000

# %%
X_city_train, X_city_test, y_city_train, y_city_test = train_test_split(X_city, Y, random_state=1)

# %%
X_city_train = X_city_train[data_clean['confidence_mean'] >=0.75]
y_city_train = y_city_train[data_clean['confidence_mean'] >=0.75]

# %%
vect = CountVectorizer(min_df=4, max_df=0.3, stop_words='english')

# %%
# Transform fit
x_dtm = vect.fit_transform(X_city_train)
x_test_dtm = vect.transform(X_city_test)

# import and instantiate a Multinomial Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

nb.fit(x_dtm, y_city_train)
y_pred_prob = nb.predict_proba(x_test_dtm)[:, 1]

from sklearn import metrics
print(metrics.roc_auc_score(y_city_test, y_pred_prob))
# Out:
# 0.849690033381

# %%
len(X_city_train)
# Out:
# 799
